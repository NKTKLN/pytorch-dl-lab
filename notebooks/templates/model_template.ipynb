# %% [markdown]
# # TODO: Model Name — Practice Notebook
#
# TODO: one or two sentences describing the task, the dataset, and what the notebook demonstrates.

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# TODO: import dataset helpers (e.g. from dl_roadmap.data import ...)
from dl_roadmap.engine import Trainer, TrainerConfig
from dl_roadmap.utils import LoggerConfig, seed_everything, setup_logger
from dl_roadmap.visualization import plot_training_history

# %%
# %matplotlib inline

pd.set_option("display.width", 150)
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", None)

seed_everything()
setup_logger(LoggerConfig(disable_logging=True))

# %% [markdown]
# ## Dataset

# %%
# TODO: load/generate the dataset and build train/val DataLoaders
# train_loader = DataLoader(train_dataset, batch_size=..., shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=..., shuffle=False)

# %%
# TODO: visualize a few samples from the dataset

# %% [markdown]
# ## Training

# %%
# TODO: define the model, optimizer, and loss function
# model = ...
# opt = torch.optim.Adam(model.parameters(), lr=1e-3)
# loss_fn = ...

trainer_config = TrainerConfig(epochs=10)
trainer = Trainer(model, opt, loss_fn, trainer_config)
history = trainer.fit(train_loader, val_loader)

# %% [markdown]
# ## Results

# %%
plot_training_history(**history)

# %%
# TODO: evaluate the trained model on the validation set (metric, table, etc.)

# %%
# TODO: visualize predictions vs ground truth
